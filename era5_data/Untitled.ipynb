# %%
pip list | grep netCDF4
# Out:
# netCDF4                   1.7.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list | grep h5netcdf
# Out:
# h5netcdf                  1.6.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
import os

# ------------- USER SETTINGS -------------
nc_path = "data_0.nc"
out_dir = "era5_rasters_bins"
os.makedirs(out_dir, exist_ok=True)

variables = ['t2m']                 # or any other variable(s)
time_indices = [0, 12, 24, 36, 47]  # hours you want

# If you know your temperature range (in Kelvin):
# For example, 10–30°C = 283.15–303.15 K
# Or set to None to use each image's min/max
temp_min, temp_max = 273.15, 303.15  # 10°C–30°C, change as needed
n_bins = 12  # Number of color bins

# ------------- SCRIPT --------------------
ds = xr.open_dataset(nc_path)

for var in variables:
    print(f"Plotting variable: {var}")
    arr_full = ds[var].values  # [time, lat, lon]
    for t in time_indices:
        arr = arr_full[t]
        arr = np.nan_to_num(arr, nan=0)

        # Dynamically set bounds if wanted
        if temp_min is not None and temp_max is not None:
            vmin, vmax = temp_min, temp_max
        else:
            vmin, vmax = np.percentile(arr, [2, 98])
        
        # Create bin edges for color mapping
        bounds = np.linspace(vmin, vmax, n_bins + 1)
        cmap = plt.get_cmap('plasma', n_bins)  # try 'jet', 'RdYlBu', etc.
        norm = BoundaryNorm(boundaries=bounds, ncolors=n_bins)

        # Plot discrete-color map
        img_name = f"{var}_hour{t:02d}_binned.png"
        plt.figure(figsize=(12,5))
        plt.axis('off')
        im = plt.imshow(arr, cmap=cmap, norm=norm, origin='upper')
        cbar = plt.colorbar(im, boundaries=bounds, ticks=bounds, fraction=0.025, pad=0.04)
        cbar.set_label(ds[var].attrs.get('long_name', var))
        plt.tight_layout(pad=0)
        plt.savefig(os.path.join(out_dir, img_name), bbox_inches='tight', pad_inches=0, dpi=200)
        plt.close()
        print(f"  Saved {img_name}")

print("Done! Check the", out_dir, "folder for color-binned PNG images.")
# Out:
# Plotting variable: t2m
#   Saved t2m_hour00_binned.png
#   Saved t2m_hour12_binned.png
#   Saved t2m_hour24_binned.png
#   Saved t2m_hour36_binned.png
#   Saved t2m_hour47_binned.png
# Done! Check the era5_rasters_bins folder for color-binned PNG images.

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
import rasterio
from rasterio.transform import from_origin
import os

nc_path = "data_0.nc"
rasters_dir = "../era5_rasters_bins"
geotiffs_dir = "../era5_geotiffs"
os.makedirs(rasters_dir, exist_ok=True)
os.makedirs(geotiffs_dir, exist_ok=True)

# Set your temp variable and fixed bounds
temp_var = 't2m'
temp_vmin, temp_vmax = 273.15, 303.15  # 0°C to 30°C

n_bins = 12

ds = xr.open_dataset(nc_path)
lat = ds.latitude.values
lon = ds.longitude.values
transform = from_origin(lon.min(), lat.max(), abs(lon[1] - lon[0]), abs(lat[1] - lat[0]))

for var in ds.data_vars:
    arr_full = ds[var].values  # [time, lat, lon]
    for t in range(arr_full.shape[0]):
        arr = arr_full[t]
        arr = np.nan_to_num(arr, nan=0)

        # -- Color bin logic --
        if var == temp_var:
            vmin, vmax = temp_vmin, temp_vmax
        else:
            vmin, vmax = np.percentile(arr, [5, 95])

        # (protect against zero-range)
        if abs(vmax - vmin) < 1e-6:
            vmax = vmin + 1e-6

        bounds = np.linspace(vmin, vmax, n_bins + 1)
        cmap = plt.get_cmap('plasma', n_bins)import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
import rasterio
from rasterio.transform import from_origin
import os

nc_path = "data_0.nc"
rasters_dir = "../era5_rasters_bins"
geotiffs_dir = "../era5_geotiffs"
os.makedirs(rasters_dir, exist_ok=True)
os.makedirs(geotiffs_dir, exist_ok=True)

# Set your temp variable and fixed bounds
temp_var = 't2m'
temp_vmin, temp_vmax = 273.15, 303.15  # 0°C to 30°C

n_bins = 12

ds = xr.open_dataset(nc_path)
lat = ds.latitude.values
lon = ds.longitude.values
transform = from_origin(lon.min(), lat.max(), abs(lon[1] - lon[0]), abs(lat[1] - lat[0]))

for var in ds.data_vars:
    arr_full = ds[var].values  # [time, lat, lon]
    for t in range(arr_full.shape[0]):
        arr = arr_full[t]
        arr = np.nan_to_num(arr, nan=0)

        # -- Color bin logic --
        if var == temp_var:
            vmin, vmax = temp_vmin, temp_vmax
        else:
            vmin, vmax = np.percentile(arr, [5, 95])

        # (protect against zero-range)
        if abs(vmax - vmin) < 1e-6:
            vmax = vmin + 1e-6

        bounds = np.linspace(vmin, vmax, n_bins + 1)
        cmap = plt.get_cmap('plasma', n_bins)
        norm = BoundaryNorm(boundaries=bounds, ncolors=n_bins)

        # PNG raster
        plt.figure(figsize=(12, 5))
        plt.axis('off')
        plt.imshow(arr, cmap=cmap, norm=norm, origin='upper')
        plt.tight_layout(pad=0)
        png_name = f"{var}_hour{t:02d}_binned.png"
        plt.savefig(os.path.join(rasters_dir, png_name), bbox_inches='tight', pad_inches=0, dpi=200)
        plt.close()

        # GeoTIFF (raw data)
        tif_name = f"{var}_hour{t:02d}.tif"
        with rasterio.open(
            os.path.join(geotiffs_dir, tif_name), 'w',
            driver='GTiff', height=arr.shape[0], width=arr.shape[1],
            count=1, dtype=arr.dtype, crs='EPSG:4326', transform=transform
        ) as dst:
            dst.write(arr, 1)
        print(f"Saved: {png_name}, {tif_name}")

print("Done!")

        norm = BoundaryNorm(boundaries=bounds, ncolors=n_bins)

        # PNG raster
        plt.figure(figsize=(12, 5))
        plt.axis('off')
        plt.imshow(arr, cmap=cmap, norm=norm, origin='upper')
        plt.tight_layout(pad=0)
        png_name = f"{var}_hour{t:02d}_binned.png"
        plt.savefig(os.path.join(rasters_dir, png_name), bbox_inches='tight', pad_inches=0, dpi=200)
        plt.close()

        # GeoTIFF (raw data)
        tif_name = f"{var}_hour{t:02d}.tif"
        with rasterio.open(
            os.path.join(geotiffs_dir, tif_name), 'w',
            driver='GTiff', height=arr.shape[0], width=arr.shape[1],
            count=1, dtype=arr.dtype, crs='EPSG:4326', transform=transform
        ) as dst:
            dst.write(arr, 1)
        print(f"Saved: {png_name}, {tif_name}")

print("Done!")
# Out:
# Saved: d2m_hour00_binned.png, d2m_hour00.tif
# Saved: d2m_hour01_binned.png, d2m_hour01.tif
# Saved: d2m_hour02_binned.png, d2m_hour02.tif
# Saved: d2m_hour03_binned.png, d2m_hour03.tif
# Saved: d2m_hour04_binned.png, d2m_hour04.tif
# Saved: d2m_hour05_binned.png, d2m_hour05.tif
# Saved: d2m_hour06_binned.png, d2m_hour06.tif
# Saved: d2m_hour07_binned.png, d2m_hour07.tif
# Saved: d2m_hour08_binned.png, d2m_hour08.tif
# Saved: d2m_hour09_binned.png, d2m_hour09.tif
# Saved: d2m_hour10_binned.png, d2m_hour10.tif
# Saved: t2m_hour18_binned.png, t2m_hour18.tif
# Saved: t2m_hour19_binned.png, t2m_hour19.tif
# Saved: t2m_hour20_binned.png, t2m_hour20.tif
# Saved: t2m_hour21_binned.png, t2m_hour21.tif
# Saved: t2m_hour22_binned.png, t2m_hour22.tif
# Saved: t2m_hour23_binned.png, t2m_hour23.tif
# Saved: t2m_hour24_binned.png, t2m_hour24.tif
# Saved: t2m_hour25_binned.png, t2m_hour25.tif
# Saved: t2m_hour26_binned.png, t2m_hour26.tif
# Saved: t2m_hour27_binned.png, t2m_hour27.tif
# Saved: t2m_hour28_binned.png, t2m_hour28.tif
# Saved: t2m_hour29_binned.png, t2m_hour29.tif
# Saved: t2m_hour30_binned.png, t2m_hour30.tif
# Saved: t2m_hour31_binned.png, t2m_hour31.tif
# Saved: t2m_hour32_binned.png, t2m_hour32.tif
# Saved: t2m_hour33_binned.png, t2m_hour33.tif
# Saved: t2m_hour34_binned.png, t2m_hour34.tif
# Saved: t2m_hour35_binned.png, t2m_hour35.tif
# Saved: t2m_hour36_binned.png, t2m_hour36.tif
# Saved: t2m_hour37_binned.png, t2m_hour37.tif
# Saved: t2m_hour38_binned.png, t2m_hour38.tif
# Saved: t2m_hour39_binned.png, t2m_hour39.tif
# Saved: t2m_hour40_binned.png, t2m_hour40.tif
# Saved: t2m_hour41_binned.png, t2m_hour41.tif
# Saved: t2m_hour42_binned.png, t2m_hour42.tif
# Saved: t2m_hour43_binned.png, t2m_hour43.tif
# Saved: t2m_hour44_binned.png, t2m_hour44.tif
# Saved: t2m_hour45_binned.png, t2m_hour45.tif
# Saved: t2m_hour46_binned.png, t2m_hour46.tif
# Saved: t2m_hour47_binned.png, t2m_hour47.tif
# Saved: skt_hour00_binned.png, skt_hour00.tif
# Saved: skt_hour01_binned.png, skt_hour01.tif
# Saved: skt_hour02_binned.png, skt_hour02.tif
# Saved: skt_hour03_binned.png, skt_hour03.tif
# Saved: skt_hour04_binned.png, skt_hour04.tif
# Saved: skt_hour05_binned.png, skt_hour05.tif
# Saved: skt_hour06_binned.png, skt_hour06.tif
# Saved: skt_hour07_binned.png, skt_hour07.tif
# Saved: skt_hour08_binned.png, skt_hour08.tif
# Saved: skt_hour09_binned.png, skt_hour09.tif
# Saved: skt_hour10_binned.png, skt_hour10.tif
# Saved: skt_hour11_binned.png, skt_hour11.tif
# Saved: skt_hour12_binned.png, skt_hour12.tif
# Saved: skt_hour13_binned.png, skt_hour13.tif
# Saved: skt_hour14_binned.png, skt_hour14.tif
# Saved: skt_hour15_binned.png, skt_hour15.tif
# Saved: skt_hour16_binned.png, skt_hour16.tif
# Saved: skt_hour17_binned.png, skt_hour17.tif
# Saved: skt_hour18_binned.png, skt_hour18.tif
# Saved: skt_hour19_binned.png, skt_hour19.tif
# Saved: skt_hour20_binned.png, skt_hour20.tif
# Saved: skt_hour21_binned.png, skt_hour21.tif
# Saved: skt_hour22_binned.png, skt_hour22.tif
# Saved: skt_hour23_binned.png, skt_hour23.tif
# Saved: skt_hour24_binned.png, skt_hour24.tif
# Saved: skt_hour25_binned.png, skt_hour25.tif
# Saved: skt_hour26_binned.png, skt_hour26.tif
# Saved: skt_hour27_binned.png, skt_hour27.tif
# Saved: stl1_hour37_binned.png, stl1_hour37.tif
# Saved: stl1_hour38_binned.png, stl1_hour38.tif
# Saved: stl1_hour39_binned.png, stl1_hour39.tif
# Saved: stl1_hour40_binned.png, stl1_hour40.tif
# Saved: stl1_hour41_binned.png, stl1_hour41.tif
# Saved: stl1_hour42_binned.png, stl1_hour42.tif
# Saved: stl1_hour43_binned.png, stl1_hour43.tif
# Saved: stl1_hour44_binned.png, stl1_hour44.tif
# Saved: stl1_hour45_binned.png, stl1_hour45.tif
# Saved: stl1_hour46_binned.png, stl1_hour46.tif
# Saved: stl1_hour47_binned.png, stl1_hour47.tif
# Saved: stl2_hour00_binned.png, stl2_hour00.tif
# Saved: stl2_hour01_binned.png, stl2_hour01.tif
# Saved: stl2_hour02_binned.png, stl2_hour02.tif
# Saved: stl2_hour03_binned.png, stl2_hour03.tif
# Saved: stl2_hour04_binned.png, stl2_hour04.tif
# Saved: stl2_hour05_binned.png, stl2_hour05.tif
# Saved: stl2_hour06_binned.png, stl2_hour06.tif
# Saved: stl2_hour07_binned.png, stl2_hour07.tif
# Saved: stl2_hour08_binned.png, stl2_hour08.tif
# Saved: stl2_hour09_binned.png, stl2_hour09.tif
# Saved: stl2_hour10_binned.png, stl2_hour10.tif
# Saved: stl2_hour11_binned.png, stl2_hour11.tif
# Saved: stl2_hour12_binned.png, stl2_hour12.tif
# Saved: stl2_hour13_binned.png, stl2_hour13.tif
# Saved: stl2_hour14_binned.png, stl2_hour14.tif
# Saved: stl2_hour15_binned.png, stl2_hour15.tif
# Saved: stl2_hour16_binned.png, stl2_hour16.tif
# Saved: stl2_hour17_binned.png, stl2_hour17.tif
# Saved: stl2_hour18_binned.png, stl2_hour18.tif
# Saved: stl2_hour19_binned.png, stl2_hour19.tif
# Saved: stl2_hour20_binned.png, stl2_hour20.tif
# Saved: stl2_hour21_binned.png, stl2_hour21.tif
# Saved: stl2_hour22_binned.png, stl2_hour22.tif
# Saved: stl2_hour23_binned.png, stl2_hour23.tif
# Saved: stl2_hour24_binned.png, stl2_hour24.tif
# Saved: stl2_hour25_binned.png, stl2_hour25.tif

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
import rasterio
from rasterio.transform import from_origin
import os, gc

# -- SETTINGS --
nc_path = "data_0.nc"
rasters_dir = "../era5_rasters_bins"
geotiffs_dir = "../era5_geotiffs"
os.makedirs(rasters_dir, exist_ok=True)
os.makedirs(geotiffs_dir, exist_ok=True)
var = 'tp'    # Change as needed

ds = xr.open_dataset(nc_path)
arr_full = ds[var].values
lat = ds.latitude.values
lon = ds.longitude.values
transform = from_origin(lon.min(), lat.max(), abs(lon[1] - lon[0]), abs(lat[1] - lat[0]))

n_bins = 12

# Use 5th-95th percentile for color limits for non-temp variables
for t in range(arr_full.shape[0]):
    arr = arr_full[t]
    arr = np.nan_to_num(arr, nan=0)
    vmin, vmax = np.percentile(arr, [5, 95])
    if abs(vmax - vmin) < 1e-6:
        vmax = vmin + 1e-6

    bounds = np.linspace(vmin, vmax, n_bins + 1)
    cmap = plt.get_cmap('plasma', n_bins)
    norm = BoundaryNorm(boundaries=bounds, ncolors=n_bins)

    # -- PNG raster --
    plt.figure(figsize=(12, 5))
    plt.axis('off')
    plt.imshow(arr, cmap=cmap, norm=norm, origin='upper')
    plt.tight_layout(pad=0)
    png_name = f"{var}_hour{t:02d}_binned.png"
    plt.savefig(os.path.join(rasters_dir, png_name), bbox_inches='tight', pad_inches=0, dpi=200)
    plt.close('all')

    # -- GeoTIFF --
    tif_name = f"{var}_hour{t:02d}.tif"
    with rasterio.open(
        os.path.join(geotiffs_dir, tif_name), 'w',
        driver='GTiff', height=arr.shape[0], width=arr.shape[1],
        count=1, dtype=arr.dtype, crs='EPSG:4326', transform=transform
    ) as dst:
        dst.write(arr, 1)
    
    print(f"Saved: {png_name}, {tif_name}")
    del arr
    gc.collect()

del arr_full, ds
gc.collect()
# Out:
# Saved: tp_hour00_binned.png, tp_hour00.tif
# Saved: tp_hour01_binned.png, tp_hour01.tif
# Saved: tp_hour02_binned.png, tp_hour02.tif
# Saved: tp_hour03_binned.png, tp_hour03.tif
# Saved: tp_hour04_binned.png, tp_hour04.tif
# Saved: tp_hour05_binned.png, tp_hour05.tif
# Saved: tp_hour06_binned.png, tp_hour06.tif
# Saved: tp_hour07_binned.png, tp_hour07.tif
# Saved: tp_hour08_binned.png, tp_hour08.tif
# Saved: tp_hour09_binned.png, tp_hour09.tif
# Saved: tp_hour10_binned.png, tp_hour10.tif
# Saved: tp_hour11_binned.png, tp_hour11.tif
# Saved: tp_hour12_binned.png, tp_hour12.tif
# Saved: tp_hour13_binned.png, tp_hour13.tif
# Saved: tp_hour14_binned.png, tp_hour14.tif
# Saved: tp_hour15_binned.png, tp_hour15.tif
# Saved: tp_hour16_binned.png, tp_hour16.tif
# Saved: tp_hour17_binned.png, tp_hour17.tif
# Saved: tp_hour18_binned.png, tp_hour18.tif
# Saved: tp_hour19_binned.png, tp_hour19.tif
# Saved: tp_hour20_binned.png, tp_hour20.tif
# Saved: tp_hour21_binned.png, tp_hour21.tif
# Saved: tp_hour22_binned.png, tp_hour22.tif
# Saved: tp_hour23_binned.png, tp_hour23.tif
# Saved: tp_hour24_binned.png, tp_hour24.tif
# Saved: tp_hour25_binned.png, tp_hour25.tif
# Saved: tp_hour26_binned.png, tp_hour26.tif
# Saved: tp_hour27_binned.png, tp_hour27.tif
# Saved: tp_hour28_binned.png, tp_hour28.tif
# Saved: tp_hour29_binned.png, tp_hour29.tif
# Saved: tp_hour30_binned.png, tp_hour30.tif
# Saved: tp_hour31_binned.png, tp_hour31.tif
# Saved: tp_hour32_binned.png, tp_hour32.tif
# Saved: tp_hour33_binned.png, tp_hour33.tif
# Saved: tp_hour34_binned.png, tp_hour34.tif
# Saved: tp_hour35_binned.png, tp_hour35.tif
# Saved: tp_hour36_binned.png, tp_hour36.tif
# Saved: tp_hour37_binned.png, tp_hour37.tif
# Saved: tp_hour38_binned.png, tp_hour38.tif
# Saved: tp_hour39_binned.png, tp_hour39.tif
# Saved: tp_hour40_binned.png, tp_hour40.tif
# Saved: tp_hour41_binned.png, tp_hour41.tif
# Saved: tp_hour42_binned.png, tp_hour42.tif
# Saved: tp_hour43_binned.png, tp_hour43.tif
# Saved: tp_hour44_binned.png, tp_hour44.tif
# Saved: tp_hour45_binned.png, tp_hour45.tif
# Saved: tp_hour46_binned.png, tp_hour46.tif
# Saved: tp_hour47_binned.png, tp_hour47.tif
# 39
